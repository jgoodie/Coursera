# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn') # or import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3 = pd.read_csv('df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha=0.5)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh()

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,6),lw=1)

# %%
df1.plot.scatter(x='A', y='B', figsize=(10,8), c='C', cmap='magma')

# %%
df1.plot.scatter(x='A', y='B', figsize=(10,8), s=df1['C']*100)
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df4 = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])
df4.head()
# Out:
#           a         b
# 0  0.068025 -0.532072
# 1 -0.795678 -1.311817
# 2  2.706514 -0.585775
# 3 -0.639718  0.745536
# 4  0.157648 -1.662869

# %%
df4.plot.hexbin(x='a', y='b', gridsize=25,cmap='coolwarm')

# %%
df2['a'].plot.kde()

# %%
df2.plot.density() #same as kde
